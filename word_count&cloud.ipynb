# %%
# !pip install mecab-python3
# !pip install wordcloud
# Out:
# Requirement already satisfied: mecab-python3 in /opt/conda/lib/python3.6/site-packages (0.996.2)
# Collecting wordcloud
#   Downloading https://files.pythonhosted.org/packages/ae/af/849edf14d573eba9c8082db898ff0d090428d9485371cc4fe21a66717ad2/wordcloud-1.5.0-cp36-cp36m-manylinux1_x86_64.whl (361kB)
#     100% |████████████████████████████████| 368kB 12.6MB/s ta 0:00:01
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.6/site-packages (from wordcloud) (1.13.3)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.6/site-packages (from wordcloud) (5.3.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.5.0

# %%
import MeCab
import csv
import pandas as pd
import collections
from wordcloud import WordCloud

# %%
csv_path = input("CSVファイルのパスを入力してください：")
df = pd.read_csv(csv_path)
df = df["作品名"]
mecab= MeCab.Tagger("")
# Out:
# CSVファイルのパスを入力してください：list_person_all_extended_utf8.csv
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
s = []
for text in df:
  node = mecab.parseToNode(text)
  while node:
    if node.feature[:2] == '名詞':
      s.append(node.surface)
    node = node.next

word_count = collections.Counter(s)
print(word_count)
# Out:
# Counter({'捕物': 573, '平次': 408, '銭形': 406, '控': 396, '話': 252, '一': 241, '二': 231, '人': 220, '十': 220, '記': 216, '手紙': 207, '日': 189, '三': 171, '日本': 168, '文学': 164, '私': 152, '日記': 147, '論': 137, '女': 135, '的': 134, '花': 126, '者': 123, '源氏物語': 119, 'さん': 116, '集': 115, '春': 112, '小説': 112, '七': 112, '年': 111, '帳': 109, '夜': 108, '雪': 102, 'こと': 100, '生活': 99, '談': 99, '家': 96, '死': 94, '物語': 91, '歌': 87, '先生': 86, '世界': 86, '山': 82, '維新': 82, '氏': 81, '夢': 80, '幕末': 80, '懐古': 80, '五': 77, '事件': 74, '婦人': 73, '文化': 71, '序': 70, '男': 70, '書': 68, '君': 68, '科学': 68, '秋': 66, '時代': 65, '中': 64, '四': 64, '海': 63, '言葉': 62, '安吾': 61, '道': 60, '子': 60, '心': 60, '芸術': 59, '怪談': 58, '作家': 57, '月': 57, '現代': 56, '殺人': 56, '詩': 56, '犬': 55, '帖': 55, '明治': 54, '猫': 54, 'もの': 54, '学': 53, '研究': 53, '葉': 53, '夏': 53, '母': 52, '就': 52, '少年': 51, '旅': 51, '性': 51, 'たち': 51, '九': 50, '窓': 49, '人間': 49, '問題': 49, '映画': 48, '会': 47, '東京': 47, '木': 47, 'あとがき': 47, '上': 46, '朝': 45, '人生': 45, '神': 44, '後': 44, '冬': 44, '探偵': 44, '風': 44, '百': 43, '八': 43, '文芸': 43, '愛': 43, '譚': 43, '大菩薩峠': 43, '録': 42, '子供': 42, '村': 42, '六': 41, '星': 41, '雨': 40, '教育': 40, '事': 39, '雑記': 39, '書簡': 39, '街': 39, '右門': 39, '樹木': 39, '国': 38, '観': 38, '前': 38, 'はなし': 38, '伝': 37, '時': 37, '父': 37, '顔': 37, '町': 37, '草': 37, '宛': 37, '歴史': 37, '画': 36, '戦争': 36, '室': 36, '篇': 36, '鬼': 35, '全集': 35, '本': 35, '島': 35, '無題': 35, '名作': 35, '行': 35, '鳥': 35, '演劇': 35, '支那': 34, '虫': 34, '怪': 34, '巻': 34, '娘': 34, '料理': 34, '水': 33, '人形': 33, '魚': 33, '主義': 32, '影': 32, '女性': 32, '風景': 32, '考': 32, '言': 31, '印象': 31, '抄': 31, '雲': 31, '号': 31, '夫人': 31, '史': 31, 'の': 31, '感想': 31, '版': 31, '郎': 31, '美': 30, '追憶': 30, '二つ': 30, '雑感': 30, '音': 30, '日本橋': 30, '火': 30, '秘密': 30, '随筆': 30, 'ため': 30, 'ジャン': 30, 'さ': 29, '森': 29, '説': 29, 'クリストフ': 29, '創作': 28, '作': 28, '桜': 28, '運動': 28, '精神': 28, '恋': 28, '石': 27, '学校': 27, '詩集': 27, '青年': 27, '紀行': 27, '法': 27, '祭': 27, '金': 27, '船': 27, '夜話': 27, '少女': 26, '頃': 26, '戯曲': 26, '黒': 26, '思想': 26, '狐': 26, '編輯': 26, '生涯': 26, '今日': 26, '下': 26, '劇': 26, '旧聞': 26, '手記': 25, '開化': 25, '一つ': 25, '作品': 25, '幸福': 25, '一幕': 25, '馬': 25, '城': 25, '思い出': 25, '灯': 25, '顎': 25, '南': 24, '社会': 24, '姫': 24, '博士': 24, '塔': 24, '文壇': 24, '後記': 24, '恋愛': 23, '人々': 23, '白': 23, '幽霊': 23, '僕': 23, '自然': 23, '師': 23, '籠': 23, '出': 23, '声': 23, '秀雄': 23, '新劇': 23, '覚書': 23, '語': 22, '酒': 22, '旅行': 22, 'ら': 22, '哲学': 22, '解説': 22, '何': 22, '場': 22, '-': 22, '奇談': 22, 'クラブ': 22, '宮本': 22, '土': 21, '妻': 21, '学生': 21, '魔': 21, '怪奇': 21, '中国': 21, 'その他': 20, '題': 20, '文': 20, '文章': 20, '小': 20, '釣': 20, '昔': 20, 'ヶ': 20, '力': 20, 'ベートーヴェン': 20, '最後': 20, '作者': 20, '眼': 20, '平和': 20, '小熊': 20, '青春': 20, '足': 20, '昭和': 20, '誰': 20, 'ディカーニカ': 20, '近郷': 20, '戦後': 20, '結婚': 19, '化': 19, '冒険': 19, '不思議': 19, '家庭': 19, '三つ': 19, '座': 19, '五月': 19, '明日': 19, '手': 19, '北': 19, '館': 19, '獄中': 19, '川': 19, '空': 19, '図書館': 19, '俳句': 19, '追放': 19, 'ソヴェト': 19, '音楽': 18, '貝殻': 18, '地獄': 18, '猿': 18, '庭': 18, '松': 18, '翻訳': 18, '友': 18, '景': 18, '大阪': 18, '味': 18, '芝居': 18, '地': 18, '屋': 18, '地方': 18, '時計': 18, '読書': 18, '大杉': 18, '栄': 18, '小僧': 18, '童話': 18, '悪魔': 17, '訳': 17, 'め': 17, '詩人': 17, '我': 17, '処女': 17, '様': 17, '譜': 17, '月夜': 17, '鏡': 17, '心理': 17, '田舎': 17, '選集': 17, '其中': 17, '伝説': 16, '彼': 16, '問答': 16, '頭': 16, '写真': 16, '赤': 16, '老人': 16, '曲': 16, '憶': 16, '挿話': 16, 'つた': 16, '風俗': 16, '余': 16, '価値': 16, '像': 16, 'はし': 16, '現実': 16, '太平': 16, '馬車': 15, '万': 15, '自分': 15, '遺書': 15, '首': 15, '図': 15, '牛': 15, '霧': 15, '絵': 15, '記憶': 15, '聖': 15, '光': 15, '実': 15, '面': 15, '原': 15, '階': 15, 'さま': 15, '巴里': 15, '名': 15, '歳': 15, '青': 15, '労働': 15, '趣味': 14, '志': 14, 'よう': 14, '車': 14, '漱石': 14, '大正': 14, '園': 14, '好き': 14, '答': 14, '庵': 14, '橋': 14, '色': 14, '心中': 14, '奇': 14, '魂': 14, '界': 14, '故郷': 14, '一夜': 14, '門': 14, '樹': 14, '夕': 14, '虹': 14, '亭': 14, '王': 14, '林': 14, '俳優': 14, '熊': 14, '都': 14, '巷談': 14, '狸': 14, '大衆': 14, '時評': 14, 'ノート': 14, '牡 ...

# %%
with open("WordCount.txt",mode = 'x') as f:
  for key in word_count:
    f.write(key + " : "+str(word_count[key])+" ")
f.close()

# %%
N_word = ''
for string in s:
  N_word += string
  N_word += ' '

# %%
font_path = input("フォントのパスを入力してください：")
wc = WordCloud(font_path,width=480,height=320,background_color="white",collocations=False)
wc.generate(N_word)
wc.to_file("wordcloud.png")
# Out:
# フォントのパスを入力してください：RictyDiminished-Regular.ttf
